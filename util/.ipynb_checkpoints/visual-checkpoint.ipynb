# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
path = "/home/wujinlin5/yqw_home/data/SoloDance_upload/train/train_parsing/target/video20/tparsing_20.png"
path2 = "/home/wujinlin5/yqw_home/data/SoloDance_upload/train/train_fg/target/video20/tfg_20.jpg"
img = cv2.imread(path)
img2 = cv2.imread(path2)
print(img.shape)

#img[img[:,:,0]==0]=0,0,128

img[img[:,:,0]==15] = 255,255,255 #白色：帽子

#print(img)
cv2.imwrite("test.png",img)

print(img.shape)

plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
plt.imshow(img)

plt.subplot(2,1,2)
plt.imshow(img2[...,::-1])



#'Background', 'Hat', 'Hair', 'Glove', 'Sunglasses', 'Upper-clothes', 'Dress', 'Coat', 'Socks', 'Pants', 'Jumpsuits', 'Scarf', 'Skirt', 
#'Face', 'Left-arm', 'Right-arm', 'Left-leg', 'Right-leg', 'Left-shoe', 'Right-shoe'

# hat=1; hair=2; sunglass=4; shirt=5; dress=6; coats=7; pant=9; 
# neck=10; scarf=11; face=13; left_arm=14; right_arm=15; 
# left_leg=16; right_leg=17; left_shoe=18, right_shoe=19

#划分成几个区域生成
#1上衣         3,5,6,7,11 
#2下衣         9,12
#3头部         1,2,4,10,13
#4四肢         14,15,16,17
#5鞋子加袜子   8,18,19


        
        
#0，背景
#1，帽子
#2，头发
#3，
#4，
#5，上衣
#6，连衣裙
#7，大衣（基本没有）
#8，袜子（基本没有）
#9，裤子
#10，脖子这块区域
#11，
#12，
#13，脸
##14，左手
##15，右手
##16，左腿
##17，右腿
##18，左鞋
##19，右鞋
# Out:
# (1080, 1920, 3)
# (1080, 1920, 3)
